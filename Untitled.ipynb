# %%
from flask import Flask, render_template, request, redirect
import requests
import simplejson
import os
import re
import pandas as pd
from bokeh.embed import components
from bokeh.plotting import figure

# %%
url = "https://www.quandl.com/api/v3/datasets/WIKI/"
ftype = ".csv"
apikey = {'api_key':'Xs8jwnLUvyXSEUzXVYz5'}

# %%
r = requests.get(url+'googl'+ftype,apikey)

# %%
a = pd.read_csv(r.url,index_col='Date',usecols = ['Date','Adj. Open', 'Adj. Close'])[::-1]

# %%
r.url
# Out:
# u'https://www.quandl.com/api/v3/datasets/WIKI/googl.csv?api_key=Xs8jwnLUvyXSEUzXVYz5'

# %%
a.index = pd.to_datetime(a.index)

# %%
a
# Out:
#             Adj. Open  Adj. Close
# Date
# 2004-08-19     50.000      50.170
# 2004-08-20     50.505      54.155
# 2004-08-23     55.375      54.700
# 2004-08-24     55.620      52.435
# 2004-08-25     52.480      53.000
# 2004-08-26     52.475      53.955
# 2004-08-27     54.050      53.075
# 2004-08-30     52.640      51.005
# 2004-08-31     51.150      51.185
# 2004-09-01     51.350      50.125
# 2004-09-02     49.595      50.755
# 2004-09-03     50.475      50.005
# 2004-09-07     50.505      50.790
# 2004-09-08     50.370      51.150
# 2004-09-09     51.265      51.155
# 2004-09-10     50.800      52.665
# 2004-09-13     53.315      53.750
# 2004-09-14     53.725      55.745
# 2004-09-15     55.280      56.000
# 2004-09-16     56.170      56.985
# 2004-09-17     57.210      58.745
# 2004-09-20     58.475      59.680
# 2004-09-21     59.905      58.920
# 2004-09-22     58.700      59.190
# 2004-09-23     59.420      60.410
# 2004-09-24     60.470      59.915
# ...

# %%
test = 'abcdef'
test.strip()
# Out:
# 'abcdef'

# %%
test.strip()
# Out:
# 'abcdef'

# %%
re.split(r"\W+" , "a, b, c, d, e")
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
'a'.upper()
# Out:
# 'A'

# %%
r
# Out:
# <Response [200]>

# %%
pd.read_csv(r.url)
# Out:
#             Date    Open      High       Low   Close      Volume  Ex-Dividend  \
# 0     2016-05-27  737.51  747.9100  737.0100  747.60   1720366.0          0.0
# 1     2016-05-26  736.00  741.1000  733.0000  736.93   1283896.0          0.0
# 2     2016-05-25  735.00  739.8900  732.6000  738.10   1606551.0          0.0
# 3     2016-05-24  719.85  734.2000  719.6450  733.03   1879157.0          0.0
# 4     2016-05-23  719.98  723.4999  716.9400  717.24   1228165.0          0.0
# 5     2016-05-20  716.46  727.7000  715.0100  721.71   1710030.0          0.0
# 6     2016-05-19  718.30  720.5000  710.3050  715.31   1488030.0          0.0
# 7     2016-05-18  718.50  725.5700  715.0200  721.78   1607604.0          0.0
# 8     2016-05-17  731.06  735.8500  718.0000  720.19   1631175.0          0.0
# 9     2016-05-16  724.32  732.6800  720.0000  730.30   1106682.0          0.0
# 10    2016-05-13  726.62  731.2900  723.5100  724.83   1224427.0          0.0
# ...

# %%
['Date', 'Close'] 
pd.read_csv('https://www.quandl.com/api/v3/datasets/WIKI/GOOGL.csv?api_key=Xs8jwnLUvyXSEUzXVYz5'
            ,index_col='Date',usecols = ['Date', 'Close'] )[::-1]
# Out:
#              Close
# Date
# 2004-08-19  100.34
# 2004-08-20  108.31
# 2004-08-23  109.40
# 2004-08-24  104.87
# 2004-08-25  106.00
# 2004-08-26  107.91
# 2004-08-27  106.15
# 2004-08-30  102.01
# 2004-08-31  102.37
# 2004-09-01  100.25
# 2004-09-02  101.51
# 2004-09-03  100.01
# 2004-09-07  101.58
# 2004-09-08  102.30
# 2004-09-09  102.31
# 2004-09-10  105.33
# 2004-09-13  107.50
# 2004-09-14  111.49
# 2004-09-15  112.00
# 2004-09-16  113.97
# 2004-09-17  117.49
# 2004-09-20  119.36
# 2004-09-21  117.84
# 2004-09-22  118.38
# 2004-09-23  120.82
# 2004-09-24  119.83
# 2004-09-27  118.26
# 2004-09-28  126.86
# 2004-09-29  131.08
# 2004-09-30  129.60
# ...            ...
# 2016-04-18  787.68
# 2016-04-19  776.25
# 2016-04-20  774.92
# 2016-04-21  780.00
# 2016-04-22  737.42
# 2016-04-25  742.21
# 2016-04-26  725.37
# 2016-04-27  721.46
# 2016-04-28  705.06
# 2016-04-29  707.88
# 2016-05-02  714.41
# 2016-05-03  708.39
# 2016-05-04  711.37
# 2016-05-05  714.71
# 2016-05-06  725.18
# ...
